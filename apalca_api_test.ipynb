# %% [markdown]
# ### alpaca api test

# %%
alpaca_key = 
alpaca_secret_key = 

head = {
    "key_id":alpaca_key,
    "secret_key":alpaca_secret_key
}

alpaca_key_id =

# %%
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockLatestQuoteRequest

# keys required for stock historical data client
api_key = "PK049ACO15YA2ADAOQZZ"
secret_key = "hzRNijPYEC0VGpcJDuFSXF6qAyp6GaMXOAhDF6Eb"
client = StockHistoricalDataClient(api_key, secret_key)

# multi symbol request - single symbol is similar
multisymbol_request_params = StockLatestQuoteRequest(symbol_or_symbols=["SPY", "GLD", "TLT"])

latest_multisymbol_quotes = client.get_stock_latest_quote(multisymbol_request_params)

gld_latest_ask_price = latest_multisymbol_quotes["GLD"].ask_price

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass


# paper=True enables paper trading
trading_client = TradingClient(api_key, secret_key , paper=True)
search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

assets = trading_client.get_all_assets(search_params)

assets
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('35b8e824-e0d2-4546-a9ec-02a8a301139f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 5787.037037037,
#      'min_trade_increment': 1e-09,
#      'name': 'Uniswap / Bitcoin',
#      'price_increment': 5e-08,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNI/BTC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('c150e086-1e75-44e6-9c2c-093bb1e93139'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 3.8793e-05,
# ...

# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# no keys required for crypto data
client = CryptoHistoricalDataClient()

request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD", "ETH/USD"],
                        timeframe=TimeFrame.Day,
                        start="2022-07-01",end="2022-08-01"
                 )

bars = client.get_crypto_bars(request_params)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 8
#       5 # no keys required for crypto data
#       6 client = CryptoHistoricalDataClient()
# ----> 8 request_params = CryptoBarsRequest(
#       9                         symbol_or_symbols=["BTC/USD", "ETH/USD"],
#      10                         timeframe=TimeFrame.Day,
#      11                         start="2022-07-01",end="2022-08-01"
#      12                  )
#      14 bars = client.get_crypto_bars(request_params)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/alpaca/data/requests.py:48, in BaseTimeseriesDataRequest.__init__(self, **data)
#      40 if (
#      41     "end" in data
#      42     and data["end"] is not None
#      43     and isinstance(data["end"], datetime)
#      44     and data["end"].tzinfo is not None
#      45 ):
# ...

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

trading_client = TradingClient(api_key ,secret_key, paper=True)

# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="SPY",
                    qty=0.023,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )

# %%
from alpaca_trade_api.rest import REST, TimeFrame
import pandas as pd

BASE_URL = "https://paper-api.alpaca.markets"
KEY_ID = api_key
SECRET_KEY = secret_key

# Instantiate REST API Connection
api = REST(key_id=KEY_ID,secret_key=SECRET_KEY,base_url="https://paper-api.alpaca.markets")

# # Fetch 1Minute historical bars of Bitcoin
bars = api.get_crypto_bars(["BTCUSD"], TimeFrame.Minute)



# # Filter data by exchange
# bars = bars[bars.exchange == 'CBSE']
# print(bars)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[30], line 12
#       9 api = REST(key_id=KEY_ID,secret_key=SECRET_KEY,base_url="https://paper-api.alpaca.markets")
#      11 # # Fetch 1Minute historical bars of Bitcoin
# ---> 12 bars = api.get_crypto_bars(["BTCUSD"], TimeFrame.Minute)
#      16 # # Filter data by exchange
#      17 # bars = bars[bars.exchange == 'CBSE']
#      18 # print(bars)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/alpaca_trade_api/rest.py:841, in REST.get_crypto_bars(self, symbol, timeframe, start, end, limit, loc)
#     834 def get_crypto_bars(self,
#     835                     symbol: Union[str, List[str]],
#     836                     timeframe: TimeFrame,
#    (...)
#     839                     limit: int = None,
#     840                     loc: str = "us") -> BarsV2:
# ...

# %% [markdown]
# # title a sample of how to use all the
# # fancy function embedded in jupyter notebook
# ## subtitle
# **bold text** a paragraph
#
# ### subsubtitle
# > a citation? [course link](https://bruinlearn.ucla.edu/courses/167284/external_tools/3779)
#
#
# > **a citation to the local file** [**test1.ipynb**](test1.ipynb)

# %%
#a set of configurations for trading
import requests as rq
import json

#set optimal portfolio for selected stocks

ticker  = ["APPL","SPY","AMZN"]
optimal_weight = [0.25,0.80,-0.05] # long apple and spy short amazon

URL= 

#get account balance

r = rq.get(URL,headers={"key","secret_key"})
info = json.loads(r.content)

account = float(info['cash'])

for i, stock in enumerate(optimal_weight):
    weight = optimal_weight[i]
    price = df_stock

    qty = (weight*accountvar)/price

    qty = qty//1

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
raw_x = np.array([i*0.1 for i in range(1,31)])
#yq xp
raw_p,raw_q  = -2,1
raw_y = raw_x**raw_p**(1/raw_q)


#yq xp
q,p = 0.7,0.7
x = raw_x**p
y = raw_y**q
plt.plot(raw_x,raw_y)
plt.plot(x,y)
